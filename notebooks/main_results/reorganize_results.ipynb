# %%
import pandas as pd
import os
from IPython.display import display

# %%
def read_csv_files_from_folder(folder_path):
    # Initialize an empty list to store DataFrames
    dfs = []

    # Get a list of files in the folder
    file_list = os.listdir(folder_path)

    # Iterate through the files in the folder
    for file_name in file_list:
        # Check if the file has a .csv extension
        if file_name.endswith(".csv"):
            file_path = os.path.join(folder_path, file_name)

            # Read the CSV file into a DataFrame
            df = pd.read_csv(file_path, index_col=0, header=0)

            # Append the DataFrame to the list
            dfs.append(df)

    # Concatenate all DataFrames into a single DataFrame
    combined_df = pd.concat(dfs, ignore_index=True)

    return combined_df

# %%
cols = ['dataset', 'method', 'fitness_rule', 'fitness', 'ACC', 'MCC', 'avg_odds_diff', 'stat_par_diff', 'eq_opp_diff', 'solution']

# %%
results = read_csv_files_from_folder('raw/')
methods = ['hifi_initializer']
for method in results.method:
    method_results = results[results.method == method]
    csv_path = f"{method.replace('_initializer','')}_results.csv"
    method_results.reset_index(drop=True, inplace=True)
    method_results[cols].to_csv(csv_path, index=False)

results
# Out:
#      overall_acc   bal_acc  avg_odds_diff  disp_imp  stat_par_diff  \
# 0       0.850525  0.771392       0.066880  0.340312       0.173488
# 1       0.846766  0.779353       0.064494  0.363015       0.180984
# 2       0.850415  0.785906       0.081516  0.339822       0.190844
# 3       0.840133  0.767829       0.106462  0.314627       0.196582
# 4       0.846545  0.779001       0.043926  0.399408       0.168972
# ..           ...       ...            ...       ...            ...
# 355     0.690000  0.613333       0.050129  1.008403       0.005952
# 356     0.685000  0.584238       0.051853  0.896186       0.088352
# 357     0.780000  0.676190       0.079917  0.880503       0.102426
# 358     0.700000  0.667041       0.070082  0.880435       0.081481
# 359     0.750000  0.692857       0.048675  0.961840       0.027831
#
#      eq_opp_diff  theil_ind       TPR       TNR       FPR  ...       MCC  \
# 0       0.067986   0.120674  0.614254  0.928529  0.071471  ...  0.579545
# 1       0.051883   0.118369  0.641681  0.917025  0.082975  ...  0.582795
# 2       0.085902   0.113030  0.656388  0.915424  0.084576  ...  0.590856
# 3       0.124546   0.121740  0.624442  0.911216  0.088784  ...  0.556916
# 4       0.018344   0.115006  0.645871  0.912131  0.087869  ...  0.575469
# ..           ...        ...       ...       ...       ...  ...       ...
# 355     0.014545   0.235770  0.766667  0.460000  0.540000  ...  0.216302
# 356     0.089461   0.137960  0.880597  0.287879  0.712121  ...  0.208490
# 357     0.034834   0.092474  0.935714  0.416667  0.583333  ...  0.429891
# 358     0.076923   0.213093  0.766917  0.567164  0.432836  ...  0.331708
# 359     0.009116   0.163678  0.835714  0.550000  0.450000  ...  0.393668
#
#      f1_score   fitness                      solution  corr  \
# 0    0.671046  0.406057   {'eta': 14.487142654408082}   NaN
# 1    0.681233  0.518301    {'eta': 1.515543976493789}   NaN
# 2    0.687745  0.504953  {'eta': 0.19950944582732782}   NaN
# 3    0.659444  0.643550    {'eta': 857.7401831846028}   NaN
# 4    0.674637  0.802619   {'eta': 0.9840000666029113}   NaN
# ..        ...       ...                           ...   ...
# 355  0.787671  0.166172    {'eta': 7.976920145205049}   NaN
# 356  0.789298  0.119030   {'eta': 3.3107727391033626}   NaN
# 357  0.856209  0.677574   {'eta': 1.7631379022062974}   NaN
# 358  0.772727  0.629918   {'eta': 1.4080802456215709}   NaN
# 359  0.823944  0.740884   {'eta': 1.9647531774369995}   NaN
#
#                                   tune_results_history     fitness_rule  \
# 0    [{'number': 0, 'value': 0.3855159993438642, 'd...       mcc_parity
# 1    [{'number': 0, 'value': 0.49221906669021215, '...         mcc_odds
# 2    [{'number': 0, 'value': 0.4460480077633387, 'd...  mcc_opportunity
# 3    [{'number': 0, 'value': 0.6780687568321817, 'd...       acc_parity
# 4    [{'number': 0, 'value': 0.7408437730403172, 'd...         acc_odds
# ..                                                 ...              ...
# 355  [{'number': 0, 'value': 0.23314606281830585, '...         mcc_odds
# 356  [{'number': 0, 'value': 0.25362046128939925, '...  mcc_opportunity
# 357  [{'number': 0, 'value': 0.737196384861608, 'da...       acc_parity
# 358  [{'number': 0, 'value': 0.4771310318031916, 'd...         acc_odds
# 359  [{'number': 0, 'value': 0.596551724137931, 'da...  acc_opportunity
#
#                method                dataset  best_solution_tf_history
# 0    hifi_initializer   adult_dataset_reader                       NaN
# 1    hifi_initializer   adult_dataset_reader                       NaN
# 2    hifi_initializer   adult_dataset_reader                       NaN
# 3    hifi_initializer   adult_dataset_reader                       NaN
# 4    hifi_initializer   adult_dataset_reader                       NaN
# ..                ...                    ...                       ...
# 355  hifi_initializer  german_dataset_reader                       NaN
# 356  hifi_initializer  german_dataset_reader                       NaN
# 357  hifi_initializer  german_dataset_reader                       NaN
# 358  hifi_initializer  german_dataset_reader                       NaN
# 359  hifi_initializer  german_dataset_reader                       NaN
#
# [360 rows x 30 columns]
